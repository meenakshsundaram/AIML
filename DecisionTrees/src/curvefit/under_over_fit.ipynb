# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


font = {'family' : 'verdana',
        'weight' : 'normal',
        'size'   : 16}

matplotlib.rc('font', **font)

# %%
from matplotlib import font_manager
font_manager.findSystemFonts()
# Out:
# ['C:\\Windows\\Fonts\\FRABK.TTF',
#  'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  'C:\\Windows\\Fonts\\IntelOneDisplayAR-Medium.ttf',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  'C:\\Windows\\Fonts\\TCCM____.TTF',
#  'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\NotoSansTamil-Medium.ttf',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\CASTELAR.TTF',
#  'C:\\Windows\\Fonts\\NotoSansTamil_Condensed-ExtraLight.ttf',
#  'C:\\Windows\\Fonts\\NotoSerifTamil_SemiCondensed-Medium.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\NotoSansTamil-Light.ttf',
#  'C:\\Windows\\Fonts\\CENTURY.TTF',
#  'C:\\Windows\\Fonts\\NotoSerifTamil_Condensed-ExtraLight.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\MATURASC.TTF',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\MAGNETOB.TTF',
# ...

# %%
num_points=1000
std=0.75
x=1*np.random.rand(num_points)-1.5
y=(x**3)-5*(x**2)-10*(x)+5+np.random.randn(num_points)*std

# %%
# underfit calculate polynomial
uf=[]
of=[]
opt=[]
for models in range(5):
    indices=np.random.randint(0,100,size=100)
    z = np.polyfit(x[indices], y[indices], 1)
    uf.append(np.poly1d(z))

    # overfit calculate polynomia
    z = np.polyfit(x[indices], y[indices], 10)
    of.append(np.poly1d(z))

    # overfit calculate polynomia
    z = np.polyfit(x[indices], y[indices], 3)
    opt.append(np.poly1d(z))

# %%
uf
# Out:
# [poly1d([ 2.49931084, 10.87385164]),
#  poly1d([ 2.41311775, 10.79565302]),
#  poly1d([ 3.03203287, 11.20981266]),
#  poly1d([ 2.60217686, 11.28440573]),
#  poly1d([ 2.74026894, 11.21358943])]

# %%
opt
# Out:
# [poly1d([ 8.58729174, 17.95674044, 11.53727645, 11.16970409]),
#  poly1d([4.04990999, 6.37213146, 2.58986901, 9.09792123]),
#  poly1d([ -0.18327693,  -7.89296105, -12.61128992,   3.86200066]),
#  poly1d([ 8.05931651, 18.87114043, 14.90349975, 13.17198838]),
#  poly1d([ 2.14554458, -0.17096419, -4.31696264,  6.94428332])]

# %%
of
# Out:
# [poly1d([  110888.59349971,  1087576.81252625,  4732847.24103811,
#         12026127.844618  , 19746686.22726837, 21878843.43642451,
#         16555993.38400576,  8444475.29427298,  2777372.25413877,
#           531770.99103303,    45015.5841278 ]),
#  poly1d([   88118.81279022,   889270.70535184,  3979635.24697754,
#         10392721.12063748, 17526515.7121378 , 19930312.46396098,
#         15466519.61343588,  8083059.29771943,  2721236.00588728,
#           532693.34352193,    46040.2226072 ]),
#  poly1d([  212749.76184254,  2159201.3968202 ,  9723305.57854687,
#         25568279.56143808, 43451627.77414151, 49837627.7572004 ,
#         39051160.10672633, 20633087.11920173,  7033073.75661258,
#          1396334.10064981,   122621.36962877]),
#  poly1d([  214027.59191637,  2173998.60701177,  9804480.47383552,
#         25836049.21012054, 44024606.60884372, 50656135.96909305,
#         39835363.14597737, 21128628.52091477,  7230312.20028473,
# ...

# %%
plt.figure(figsize=[10,10])
plt.scatter(x,y,alpha=0.25)
h1=plt.plot(np.sort(x),uf[0](np.sort(x)),'-r')
h2=plt.plot(np.sort(x),of[0](np.sort(x)),'-g')
#h3=plt.plot(np.sort(x),opt[0](np.sort(x)),'-k')
plt.plot(np.sort(x),uf[1](np.sort(x)),'--r')
plt.plot(np.sort(x),of[1](np.sort(x)),'--g')
#plt.plot(np.sort(x),opt[1](np.sort(x)),'--k')
plt.plot(np.sort(x),uf[2](np.sort(x)),'-.r')
plt.plot(np.sort(x),of[2](np.sort(x)),'-.g')
#plt.plot(np.sort(x),opt[2](np.sort(x)),'-.k')
plt.legend(['Data','Underfit','Overfit'])
plt.show()
plt.close()
